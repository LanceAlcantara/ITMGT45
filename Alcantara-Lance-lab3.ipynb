# %% [markdown]
# 190151
#
# Alcantara
#
# 2 - BS ITE

# %%
social_graph={
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[   
                  ]
    },
    "@joaquin": {"first_name":"Joaquin",
                 "last_name":"Gonzales",
                 "following":[
                     "@chums","@jobenilagan"
                 ]
    },
    "@chums": {"first_name":"Matthew",
               "last_name":"Uy",
               "following":[
                     "@bongolpoc","@miketan","rudyang","@joeilagan"
                 ]
    },
    "@jobenilagan": {"first_name":"Joben",
                     "last_name":"Ilagan",
                     "following":[
                     "@eeebeee","@joeilagan","@chums","@joaquin"
                 ]
    },
    "@joeilagan": {"first_name":"Joe",
                 "last_name":"Ilagan",
                 "following":[
                     "@eeebeee","@jobenilagan","@chums"
                 ]
    },
    "@eeebeee": {"first_name":"Elizabeth",
                 "last_name":"Ilagan",
                 "following":[
                     "@jobenilagan","@joeilagan"
                 ]
    },
}

def relationship_status(from_member, to_member):
    try:
        if to_member in social_graph[from_member]["following"] and from_member in social_graph[to_member]["following"]:
            print(f"{from_member} and {to_member} are friends")
        elif to_member in social_graph[from_member]["following"]:
            print(f"{from_member} is following {to_member}")
        elif from_member in social_graph[to_member]["following"]:
            print(f"{from_member} is being followed by {to_member}")
        else:
            print("The two users bear no relation")
    except:
        print("name can't be found")
        

first_user = input("Name a user: ")
second_user = input("Name another user: ")
relationship_status(first_user, second_user)
# Out:
# Name a user: @eeebeee
# Name another user: @joeilagan
# @eeebeee and @joeilagan are friends

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

def who_wins(board): # made list of all possible ways to win
        if board[0][0] == board[0][1] == board[0][2]: #horizontal
            return board[0][0] 
        elif board[1][0] == board[1][1] == board[1][2]: #horizontal
            return board[1][0] 
        elif board[2][0] == board[2][1] == board[2][2]: #horizontal
            return board[2][0] 
        elif board[0][0] == board[1][0] == board[2][0]: #vertical
            return board[0][0] 
        elif board[0][1] == board[1][1] == board[2][1]: #vertical
            return board[0][1] 
        elif board[0][2] == board[1][2] == board[2][2]: #vertical
            return board[0][2] 
        elif board[0][0] == board[1][1] == board[2][2]: #diagonal
            return board[0][0] 
        elif board [0][2] == board[1][1] == board[2,0]: #diagonal
            return board [0][2]
        else:
            return None
            
print(who_wins(board3))
# Out:
# O

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}

source=input("Choose Source- UPD, ADMU, and DLSU: ")
destination=input("Choose Destination- UPD, ADMU, and DLSU: ")

def eta(source, destination):
    if(source=="UPD") and (destination=="ADMU"):
        est = "10"
    elif (source=="ADMU") and (destination=="DLSU"):
        est = "35"
    elif (source=="DLSU") and (destination=="UPD"):
        est = "55"
    elif (source=="UPD") and (destination=="DLSU"):
        est = "45"
    elif (source=="ADMU") and (destination=="UPD"):
        est = "90"
    elif (source=="DLSU") and (destination=="ADMU"):
        est = "65"
    return est

print("Estimated Time of Arrival is", eta(source,destination), "minutes")
# Out:
# Choose Source- UPD, ADMU, and DLSU: UPD
# Choose Destination- UPD, ADMU, and DLSU: DLSU
# Estimated Time of Arrival is 45 minutes
